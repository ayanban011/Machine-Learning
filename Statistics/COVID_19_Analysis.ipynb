# %% [markdown]
# <a href="https://colab.research.google.com/github/ayanbabusona/tensorflow/blob/master/COVID_19_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **COVID-19 DATA ANALYSIS**:

# %%
# import all the libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print("libraries are imported")
# Out:
# libraries are imported

# %%
#importing the dataset
corona_dataset_csv=pd.read_csv('time_series_covid19_confirmed_global.csv')
corona_dataset_csv.head()
# Out:
#   Province/State Country/Region      Lat  ...  6/6/20  6/7/20  6/8/20
# 0            NaN    Afghanistan  33.0000  ...   19551   20342   20917
# 1            NaN        Albania  41.1533  ...    1232    1246    1263
# 2            NaN        Algeria  28.0339  ...   10050   10154   10265
# 3            NaN        Andorra  42.5063  ...     852     852     852
# 4            NaN         Angola -11.2027  ...      88      91      92
#
# [5 rows x 143 columns]

# %%
#the shape of the datset to find the rows and coloumns
corona_dataset_csv.shape
# Out:
# (266, 143)

# %%
#deleting unnecessary coloumns
corona_dataset_csv.drop(["Lat","Long"],axis=1,inplace=True)
corona_dataset_csv.head()
# Out:
#   Province/State Country/Region  1/22/20  ...  6/6/20  6/7/20  6/8/20
# 0            NaN    Afghanistan        0  ...   19551   20342   20917
# 1            NaN        Albania        0  ...    1232    1246    1263
# 2            NaN        Algeria        0  ...   10050   10154   10265
# 3            NaN        Andorra        0  ...     852     852     852
# 4            NaN         Angola        0  ...      88      91      92
#
# [5 rows x 141 columns]

# %%
#check the shape again
corona_dataset_csv.shape
# Out:
# (266, 141)

# %%
#Aggregating the rows by the country
corona_dataset_aggregated = corona_dataset_csv.groupby("Country/Region").sum()
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  ...  6/6/20  6/7/20  6/8/20
# Country/Region                             ...
# Afghanistan           0        0        0  ...   19551   20342   20917
# Albania               0        0        0  ...    1232    1246    1263
# Algeria               0        0        0  ...   10050   10154   10265
# Andorra               0        0        0  ...     852     852     852
# Angola                0        0        0  ...      88      91      92
#
# [5 rows x 139 columns]

# %%
#Visualizing data related to country
corona_dataset_aggregated.loc["India"].plot()
corona_dataset_aggregated.loc["China"].plot()
corona_dataset_aggregated.loc["Italy"].plot()
plt.legend()

# %%
#Calculating a good measure
#we need to find a good measure reperestend as a number, describing the spread of the virus in a country.
corona_dataset_aggregated.loc['China'].plot()

# %%
#caculating the first derivative of the curve
corona_dataset_aggregated.loc['China'].diff().plot()

# %%
#find maxmimum infection rate for China
corona_dataset_aggregated.loc['China'].diff().max()
# Out:
# 15136.0

# %%
#find maxmimum infection rate for Italy
corona_dataset_aggregated.loc['Italy'].diff().max()
# Out:
# 6557.0

# %%
#find maximum infection rate for all of the countries.
countries = list(corona_dataset_aggregated.index)
max_infection_rates = []
for country in countries :
    max_infection_rates.append(corona_dataset_aggregated.loc[country].diff().max())
corona_dataset_aggregated['maximum infection rate'] = max_infection_rates

corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  ...  max infection rate  maximum infection rate
# Country/Region                    ...
# Afghanistan           0        0  ...               915.0                   915.0
# Albania               0        0  ...                34.0                    34.0
# Algeria               0        0  ...               199.0                   199.0
# Andorra               0        0  ...                79.0                    79.0
# Angola                0        0  ...                 8.0                     8.0
#
# [5 rows x 141 columns]

# %%
#create a new dataframe with only needed column
corona_data = pd.DataFrame(corona_dataset_aggregated['maximum infection rate'])
corona_data.head()
# Out:
#                 maximum infection rate
# Country/Region
# Afghanistan                      915.0
# Albania                           34.0
# Algeria                          199.0
# Andorra                           79.0
# Angola                             8.0

# %% [markdown]
#     1)Importing the WorldHappinessReport.csv dataset
#     2)join the datasets
#     3)calculate the correlations as the result of our analysis

# %%
#importing the dataset
world_happiness_report = pd.read_csv("/content/datasets_569763_1033439_WHR20_DataForFigure2.1.csv")
world_happiness_report.head()
# Out:
#   Country name  ... Dystopia + residual
# 0      Finland  ...            2.762835
# 1      Denmark  ...            2.432741
# 2  Switzerland  ...            2.350267
# 3      Iceland  ...            2.460688
# 4       Norway  ...            2.168266
#
# [5 rows x 20 columns]

# %%
#changing the indices of the dataframe
world_happiness_report.set_index(['Country name'],inplace=True)
world_happiness_report.head()
# Out:
#              Regional indicator  ...  Dystopia + residual
# Country name                     ...
# Finland          Western Europe  ...             2.762835
# Denmark          Western Europe  ...             2.432741
# Switzerland      Western Europe  ...             2.350267
# Iceland          Western Europe  ...             2.460688
# Norway           Western Europe  ...             2.168266
#
# [5 rows x 19 columns]

# %%
#we made this datashet in previous
corona_data.head()
# Out:
#                 maximum infection rate
# Country/Region
# Afghanistan                      915.0
# Albania                           34.0
# Algeria                          199.0
# Andorra                           79.0
# Angola                             8.0

# %%
#join the two dataset we have created
data=world_happiness_report.join(corona_data).copy()
data.head()
# Out:
#              Regional indicator  ...  maximum infection rate
# Country name                     ...
# Finland          Western Europe  ...                   267.0
# Denmark          Western Europe  ...                   391.0
# Switzerland      Western Europe  ...                  1321.0
# Iceland          Western Europe  ...                    99.0
# Norway           Western Europe  ...                   386.0
#
# [5 rows x 20 columns]

# %%
#correlation matrix
data.corr()
# Out:
#                                             Ladder score  ...  maximum infection rate
# Ladder score                                1.000000e+00  ...            1.729519e-01
# Standard error of ladder score             -4.464433e-01  ...           -2.349068e-01
# upperwhisker                                9.995772e-01  ...            1.677531e-01
# lowerwhisker                                9.996007e-01  ...            1.778612e-01
# Logged GDP per capita                       7.753744e-01  ...            1.927386e-01
# Social support                              7.650008e-01  ...            1.407334e-01
# Healthy life expectancy                     7.703163e-01  ...            2.025157e-01
# Freedom to make life choices                5.905968e-01  ...            7.088917e-02
# Generosity                                  6.904313e-02  ...           -1.146532e-01
# Perceptions of corruption                  -4.183051e-01  ...           -3.763056e-02
# ...

# %%
#visualising the results
#plotting maximum infection rate vs GDP
y=data["maximum infection rate"]
x=data["Logged GDP per capita"]
sns.regplot(x,np.log(y))

# %%
#plotting maximum infection rate vs social support
x=data["Social support"]
y=data["maximum infection rate"]
sns.regplot(x,np.log(y))

# %%
#plotting maximum infection rate vs Freedom to make life choices 
x=data["Freedom to make life choices"]
y=data["maximum infection rate"]
sns.regplot(x,np.log(y))

# %%
#plotting maximum infection rate vs Healthy life expectancy 
x=data["Healthy life expectancy"]
y=data["maximum infection rate"]
sns.regplot(x,np.log(y))

# %% [markdown]
# From the abobe analysis we can say that western countries are more prone towards corona infection.We can easily see by visualisation
